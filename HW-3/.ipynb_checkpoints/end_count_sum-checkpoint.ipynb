# %%
b = 0
while True:
    a = input('Введите число или cтоп для выхода: ')
    if not a.isdigit():
        if a == 'стоп' or 'Стоп':
            print (b)
            break
        else:
            print ('Ошибка ввода!')
    else:
        b += int(a)
