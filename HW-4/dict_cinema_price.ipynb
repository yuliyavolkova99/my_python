# %%
from pprint import pprint

cinema = {'Пятница':{'time_price': {12: 250, 16: 350, 20: 450},'genre': 'комедия', 'age': '16'},
 'Чемпионы':{'time_price':{10: 250, 13: 350, 16: 350},'genre': 'спорт', 'age': '16'},
 'Пернатая банда':{'time_price':{10: 350, 14: 450, 18: 450},'genre': 'мультфильм', 'age': '6'}}

pprint(cinema)
# Out:
# {'Пернатая банда': {'age': '6',
#                     'genre': 'мультфильм',
#                     'time_price': {10: 350, 14: 450, 18: 450}},
#  'Пятница': {'age': '16',
#              'genre': 'комедия',
#              'time_price': {12: 250, 16: 350, 20: 450}},
#  'Чемпионы': {'age': '16',
#               'genre': 'спорт',
#               'time_price': {10: 250, 13: 350, 16: 350}}}
